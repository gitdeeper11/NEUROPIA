# %% [markdown]
# # NEUROPIA - GCN Constraints
# ## 9 Conservation Laws as Hard Constraints

# %%
from neuropia import GrandConstraintNetwork
model = GrandConstraintNetwork()
print('GCN ready')
