# %% [markdown]
# # NEUROPIA - O-SFO Walkthrough
# ## Omni-Spectral Fourier Operator (Equation 3-4)

# %%
from neuropia import OmniSpectralFourierOperator
model = OmniSpectralFourierOperator()
print('O-SFO ready')
