# %% [markdown]
# # NEUROPIA - UFR Control
# ## Unified Flux Resolver (Equation 8)

# %%
from neuropia import UnifiedFluxResolver
model = UnifiedFluxResolver()
print('UFR ready')
